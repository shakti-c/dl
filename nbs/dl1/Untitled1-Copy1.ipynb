# %%
# Python module to randomly download images

# %%
from fastai.vision import *

# %%
download_images('all_food_urls.txt', './food_images', max_pics=50000)
# Out:
# Error http://health.cdqss.com/Files/adminfiles/zhouhmjk/090611/1G44G4T60.jpg HTTPConnectionPool(host='health.cdqss.com', port=80): Max retries exceeded with url: /Files/adminfiles/zhouhmjk/090611/1G44G4T60.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa3d8dfe080>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error http://www.qyfs.gov.cn/ysjk/W020080121386786563874.jpg HTTPConnectionPool(host='www.qyfs.gov.cn', port=80): Max retries exceeded with url: /ysjk/W020080121386786563874.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa3d8df7278>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
verify_images('./food_images', delete=True)
# Out:
# cannot identify image file <_io.BufferedReader name='food_images/00011342.JPG'>
# cannot identify image file <_io.BufferedReader name='food_images/00011836.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00002367.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00011151.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00010063.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00001775.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00004267.gif'>
# cannot identify image file <_io.BufferedReader name='food_images/00007549.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00009943.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00009703.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00011206.jpg'>
# cannot identify image file <_io.BufferedReader name='food_images/00002702.jpg'>
# ...
